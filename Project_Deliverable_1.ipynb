# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-536623f7-209f-4ce1-8a83-9fe2e0295d90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-536623f7-209f-4ce1-8a83-9fe2e0295d90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('mobile phone usage .csv', encoding='utf-8-sig')
df.head()        # Show first 5 rows
df.info()        # Show data types and non-null counts
df.describe()    # Summary statistics for numeric columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ï»¿name              225 non-null    object
#  1   slug                 225 non-null    object
#  2   value                225 non-null    object
#  3   date_of_information  225 non-null    int64
#  4   ranking              225 non-null    int64
#  5   region               225 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 10.7+ KB
#        date_of_information     ranking
# count           225.000000  225.000000
# mean           2022.075556  113.000000
# std               2.492592   65.096083
# min            2004.000000    1.000000
# 25%            2022.000000   57.000000
# 50%            2023.000000  113.000000
# 75%            2023.000000  169.000000
# max            2023.000000  225.000000

# %%
# Convert 'value' column to numeric after removing commas
df['value'] = df['value'].str.replace(',', '').astype(float)

# Check missing values
print(df.isnull().sum())

# Fill missing 'value' with median
df['value'] = df['value'].fillna(df['value'].median())

# Drop rows missing 'region'
df = df.dropna(subset=['region'])

# Remove duplicate rows if any
df = df.drop_duplicates()
# Out:
# ï»¿name                0
# slug                   0
# value                  0
# date_of_information    0
# ranking                0
# region                 0
# dtype: int64

# %%
print(df.columns[0])  # prints something like 'ï»¿name'
# Then use that exact string in plotting
top10 = df.sort_values(by='value', ascending=False).head(10)
plt.figure(figsize=(10,6))
sns.barplot(x='value', y='ï»¿name', data=top10)
plt.title('Top 10 Countries by Mobile Phone Usage')
plt.show()
# Out:
# ï»¿name
